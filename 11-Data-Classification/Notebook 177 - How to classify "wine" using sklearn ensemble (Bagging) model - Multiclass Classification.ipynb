# %% [markdown]
# # How to classify "wine" using sklearn ensemble (Bagging) model - Multiclass Classification

# %%
## How to classify "wine" using sklearn ensemble (Bagging) model - Multiclass Classification
## DataSet: skleran.datasets.load_wine()
def Snippet_177(): 
    print()
    print(format('How to classify "wine" using sklearn ensemble (Bagging) model - Multiclass Classification','*^82'))    
    import warnings
    warnings.filterwarnings("ignore")
    # load libraries
    from sklearn import datasets
    from sklearn import metrics
    from sklearn.model_selection import train_test_split
    import matplotlib.pyplot as plt    
    
    plt.style.use('ggplot')

    from sklearn import ensemble
    # load the iris datasets
    dataset = datasets.load_wine()
    X = dataset.data; y = dataset.target
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
    
    # fit a ensemble.BaggingClassifier() model to the data
    model = ensemble.BaggingClassifier()
    model.fit(X_train, y_train)
    print(); print(model)
    # make predictions
    expected_y  = y_test
    predicted_y = model.predict(X_test)
    # summarize the fit of the model
    print(); print('ensemble.BaggingClassifier(): ')
    print(); print(metrics.classification_report(expected_y, predicted_y, 
                   target_names=dataset.target_names))
    print(); print(metrics.confusion_matrix(expected_y, predicted_y))

    # fit a ensemble.ExtraTreesClassifier() model to the data
    model = ensemble.ExtraTreesClassifier()
    model.fit(X_train, y_train)
    print(); print(model)
    # make predictions
    expected_y  = y_test
    predicted_y = model.predict(X_test)
    # summarize the fit of the model
    print(); print('ensemble.ExtraTreesClassifier(): ')
    print(); print(metrics.classification_report(expected_y, predicted_y, 
                   target_names=dataset.target_names))
    print(); print(metrics.confusion_matrix(expected_y, predicted_y))
    
    # fit a ensemble.RandomForestClassifier() model to the data
    model = ensemble.RandomForestClassifier()
    model.fit(X_train, y_train)
    print(); print(model)
    # make predictions
    expected_y  = y_test
    predicted_y = model.predict(X_test)
    # summarize the fit of the model
    print(); print('ensemble.RandomForestClassifier(): ')
    print(); print(metrics.classification_report(expected_y, predicted_y, 
                   target_names=dataset.target_names))
    print(); print(metrics.confusion_matrix(expected_y, predicted_y))    
Snippet_177()
# Out:
# How to classify "wine" using sklearn ensemble (Bagging) model - Multiclass Classification
#
# BaggingClassifier(base_estimator=None, bootstrap=True,
#          bootstrap_features=False, max_features=1.0, max_samples=1.0,
#          n_estimators=10, n_jobs=None, oob_score=False, random_state=None,
#          verbose=0, warm_start=False)
#
# ensemble.BaggingClassifier():
#
#               precision    recall  f1-score   support
#
#      class_0       0.93      1.00      0.97        14
#      class_1       1.00      0.94      0.97        18
#      class_2       1.00      1.00      1.00        13
#
#    micro avg       0.98      0.98      0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
#
#
# [[14  0  0]
#  [ 1 17  0]
#  [ 0  0 13]]
#
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
# ...
