# %% [markdown]
# # How to classify "wine" using sklearn ensemble (Boosting) model - Multiclass Classification

# %%
## How to classify "wine" using sklearn ensemble (Boosting) model - Multiclass Classification
## DataSet: skleran.datasets.load_wine()
def Snippet_178(): 
    print()
    print(format('How to classify "wine" using sklearn ensemble (Bagging) model - Multiclass Classification','*^82'))    
    import warnings
    warnings.filterwarnings("ignore")
    # load libraries
    from sklearn import datasets
    from sklearn import metrics
    from sklearn.model_selection import train_test_split
    import matplotlib.pyplot as plt    
    
    plt.style.use('ggplot')

    from sklearn import ensemble
    # load the iris datasets
    dataset = datasets.load_wine()
    X = dataset.data; y = dataset.target
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
    
    # fit a ensemble.AdaBoostClassifier() model to the data
    model = ensemble.AdaBoostClassifier()
    model.fit(X_train, y_train)
    print(); print(model)
    # make predictions
    expected_y  = y_test
    predicted_y = model.predict(X_test)
    # summarize the fit of the model
    print(); print('ensemble.AdaBoostClassifier(): ')
    print(); print(metrics.classification_report(expected_y, predicted_y, 
                   target_names=dataset.target_names))
    print(); print(metrics.confusion_matrix(expected_y, predicted_y))

    # fit a ensemble.GradientBoostingClassifier() model to the data
    model = ensemble.GradientBoostingClassifier()
    model.fit(X_train, y_train)
    print(); print(model)
    # make predictions
    expected_y  = y_test
    predicted_y = model.predict(X_test)
    # summarize the fit of the model
    print(); print('ensemble.GradientBoostingClassifier(): ')
    print(); print(metrics.classification_report(expected_y, predicted_y, 
                   target_names=dataset.target_names))
    print(); print(metrics.confusion_matrix(expected_y, predicted_y))
Snippet_178()
# Out:
# How to classify "wine" using sklearn ensemble (Bagging) model - Multiclass Classification
#
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None)
#
# ensemble.AdaBoostClassifier():
#
#               precision    recall  f1-score   support
#
#      class_0       0.76      1.00      0.86        16
#      class_1       1.00      0.71      0.83        17
#      class_2       1.00      1.00      1.00        12
#
#    micro avg       0.89      0.89      0.89        45
#    macro avg       0.92      0.90      0.90        45
# weighted avg       0.92      0.89      0.89        45
#
#
# [[16  0  0]
#  [ 5 12  0]
#  [ 0  0 12]]
#
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
# ...
